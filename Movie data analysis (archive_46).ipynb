# %% [markdown]
# Movie data analysis (archive_46)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\USER\Desktop\archive_46\top10K-TMDB-movies.csv")
df
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                  genre original_language  \
# 0                                          Drama,Crime                en
# 1                                 Comedy,Drama,Romance                hi
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)
df
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                  genre original_language  \
# 0                                          Drama,Crime                en
# 1                                 Comedy,Drama,Romance                hi
# ...

# %%
df = pd.read_csv(r"C:\Users\USER\Desktop\archive_46\top10K-TMDB-movies.csv", index_col= 'title')
df
# Out:
#                                                    id  \
# title
# The Shawshank Redemption                          278
# Dilwale Dulhania Le Jayenge                     19404
# The Godfather                                     238
# Schindler's List                                  424
# The Godfather: Part II                            240
# ...                                               ...
# The Last Airbender                              10196
# Sharknado 3: Oh Hell No!                       331446
# Captain America                                 13995
# In the Name of the King: A Dungeon Siege Tale    2312
# Domino                                         455957
#
#                                                                                           genre  \
# title
# The Shawshank Redemption                                                            Drama,Crime
# Dilwale Dulhania Le Jayenge                                                Comedy,Drama,Romance
# ...

# %%
df = pd.read_csv(r"C:\Users\USER\Desktop\archive_46\top10K-TMDB-movies.csv", index_col= 'original_language')
df
# Out:
#                        id                                          title  \
# original_language
# en                    278                       The Shawshank Redemption
# hi                  19404                    Dilwale Dulhania Le Jayenge
# en                    238                                  The Godfather
# en                    424                               Schindler's List
# en                    240                         The Godfather: Part II
# ...                   ...                                            ...
# en                  10196                             The Last Airbender
# en                 331446                       Sharknado 3: Oh Hell No!
# en                  13995                                Captain America
# en                   2312  In the Name of the King: A Dungeon Siege Tale
# en                 455957                                         Domino
#
#                                                               genre  \
# ...

# %%
df.nunique()
# Out:
# id              10000
# title            9661
# genre            2123
# overview         9985
# popularity       8511
# release_date     6113
# vote_average       42
# vote_count       3191
# dtype: int64

# %%
df.sort_values
# Out:
# <bound method DataFrame.sort_values of                        id                                          title  \
# original_language
# en                    278                       The Shawshank Redemption
# hi                  19404                    Dilwale Dulhania Le Jayenge
# en                    238                                  The Godfather
# en                    424                               Schindler's List
# en                    240                         The Godfather: Part II
# ...                   ...                                            ...
# en                  10196                             The Last Airbender
# en                 331446                       Sharknado 3: Oh Hell No!
# en                  13995                                Captain America
# en                   2312  In the Name of the King: A Dungeon Siege Tale
# en                 455957                                         Domino
#
# ...

# %%
df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of                       id  title  genre  overview  popularity  release_date  \
# original_language
# en                 False  False  False     False       False         False
# hi                 False  False  False     False       False         False
# en                 False  False  False     False       False         False
# en                 False  False  False     False       False         False
# en                 False  False  False     False       False         False
# ...                  ...    ...    ...       ...         ...           ...
# en                 False  False  False     False       False         False
# en                 False  False  False     False       False         False
# en                 False  False  False     False       False         False
# en                 False  False  False     False       False         False
# ...

# %%
df.sort_values(by = "popularity")
# Out:
#                        id                     title  \
# original_language
# ja                  92321        Hotarubi no Mori e
# en                 174323                    G.B.F.
# fr                 182219           Serial Teachers
# ja                  12477    Grave of the Fireflies
# it                  11367            Odds and Evens
# ...                   ...                       ...
# en                 756999           The Black Phone
# en                 361743         Top Gun: Maverick
# en                 616037    Thor: Love and Thunder
# en                 438148  Minions: The Rise of Gru
# en                 507086   Jurassic World Dominion
#
#                                                        genre  \
# original_language
# ja                                 Romance,Animation,Fantasy
# en                                              Comedy,Drama
# fr                                                    Comedy
# ...

# %%
df.sort_values(by = "popularity").head()
# Out:
#                        id                   title                      genre  \
# original_language
# ja                  92321      Hotarubi no Mori e  Romance,Animation,Fantasy
# en                 174323                  G.B.F.               Comedy,Drama
# fr                 182219         Serial Teachers                     Comedy
# ja                  12477  Grave of the Fireflies        Animation,Drama,War
# it                  11367          Odds and Evens        Comedy,Crime,Action
#
#                                                             overview  \
# original_language
# ja                 One hot summer day a little girl gets lost in ...
# en                 The bitter fight for supremacy between the thr...
# fr                 With only 12 percent of its pupils obtaining t...
# ja                 In the final months of World War II, 14-year-o...
# it                 A bumbling government agent recruits a trucker...
#
# ...

# %%
df.sort_values(by = "popularity", ascending=False).head()
# Out:
#                        id                     title  \
# original_language
# en                 507086   Jurassic World Dominion
# en                 438148  Minions: The Rise of Gru
# en                 616037    Thor: Love and Thunder
# en                 361743         Top Gun: Maverick
# en                 756999           The Black Phone
#
#                                                        genre  \
# original_language
# en                          Adventure,Action,Science Fiction
# en                 Family,Animation,Adventure,Comedy,Fantasy
# en                                  Action,Adventure,Fantasy
# en                                              Action,Drama
# en                                           Horror,Thriller
#
#                                                             overview  \
# original_language
# en                 Four years after Isla Nublar was destroyed, di...
# en                 A fanboy of a supervillain supergroup known as...
# ...

# %%
df.sort_values(by = "popularity", ascending=False).head(10)
# Out:
#                        id                                        title  \
# original_language
# en                 507086                      Jurassic World Dominion
# en                 438148                     Minions: The Rise of Gru
# en                 616037                       Thor: Love and Thunder
# en                 361743                            Top Gun: Maverick
# en                 756999                              The Black Phone
# en                 718789                                    Lightyear
# en                 453395  Doctor Strange in the Multiverse of Madness
# en                 759175                                 The Princess
# en                 836225                          The Exorcism of God
# en                 560057                                The Sea Beast
#
#                                                                genre  \
# original_language
# en                                  Adventure,Action,Science Fiction
# ...

# %%
df[df['title'].str.contains('popularity')]
df
# Out:
#                        id                                          title  \
# original_language
# en                    278                       The Shawshank Redemption
# hi                  19404                    Dilwale Dulhania Le Jayenge
# en                    238                                  The Godfather
# en                    424                               Schindler's List
# en                    240                         The Godfather: Part II
# ...                   ...                                            ...
# en                  10196                             The Last Airbender
# en                 331446                       Sharknado 3: Oh Hell No!
# en                  13995                                Captain America
# en                   2312  In the Name of the King: A Dungeon Siege Tale
# en                 455957                                         Domino
#
#                                                               genre  \
# ...

# %%
print(plt.style.available)
plt.style.use('dark_background')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
df = df.set_index('popularity')
df
# Out:
#                 id                                          title  \
# popularity
# 94.08          278                       The Shawshank Redemption
# 25.41        19404                    Dilwale Dulhania Le Jayenge
# 90.58          238                                  The Godfather
# 44.76          424                               Schindler's List
# 57.75          240                         The Godfather: Part II
# ...            ...                                            ...
# 98.32        10196                             The Last Airbender
# 12.49       331446                       Sharknado 3: Oh Hell No!
# 18.33        13995                                Captain America
# 15.16         2312  In the Name of the King: A Dungeon Siege Tale
# 16.48       455957                                         Domino
#
#                                                        genre  \
# popularity
# 94.08                                            Drama,Crime
# ...

# %%
df.plot()
# Out:
# <Axes: xlabel='popularity'>

# %%
df.plot(kind = 'line')
# Out:
# <Axes: xlabel='popularity'>
